# %% [markdown]
# # Interpretace a prezentace dat
#
# ## Hodnocení
#
# - 2 Seminární práce po 50 %
#
# ## Program
#
# 1. úvod, instalace, první program
# 2. datové typy I
# 3. datové typy II
# 4. logické operace, podmínky, cykly
# 5. cykly, výjimky, matematické operace, numpy
# 6. funkce
# 7. import dat (csv, json, xml, Excel)
# 8. grafické moduly I: matplotlib
# 9. grafické moduly II: ggplot
# 10. Přehled API (Twitter, banky apod.)
# 11. pandas, beautiful soup
# 12. scipy
